# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ceciliabolanos/research-assistant//blob/main/ScientificGPT.ipynb)
#
# # Requirements

# %%
# clone repository
# !git clone https://github.com/ceciliabolanos/research-assistant.git
# %cd research-assistant

# %%
# install dependencies
# !apt-get install tree
# !pip install -r requirements.txt --quiet
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install accelerate  --quiet
# !pip install bitsandbytes  --quiet
# !pip install -q -U git+https://github.com/huggingface/transformers.git@main  --quiet
# !pip install -q -U git+https://github.com/huggingface/peft.git  --quiet

# %% [markdown]
# # Use the model

# %% [markdown]
# The only requirement for the following is to have a huggingface and OpenAI API KEY

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !huggingface-cli login

# %% [markdown]
# Path to download UnixCoder finetuned https://drive.google.com/file/d/1WNwdU47rkk5xm3LjB1Wx-8mR_ZmDfibR/view?usp=sharing

# %% [markdown]
# **To see how it works, specify the parameters 'GitHub', 'Mistral', and 'Chat Model'.**

# %%
# !python main.py --github_url "https://github.com/ankitapasad/layerwise-analysis.git" --model_path '/content/drive/My Drive/unixcoder-ft.bin' --mistral 'yes' --chat_model "gpt-3.5-turbo-0125"
